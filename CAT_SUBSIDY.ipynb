# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit198181/JBVNL/blob/main/CAT_SUBSIDY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import io
import pandas as pd

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-abacae0b-bdbe-459b-9b0c-c7ec20d1caed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-abacae0b-bdbe-459b-9b0c-c7ec20d1caed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

file_name = 'subsidy_sheet.xlsx'

# Load the Excel file into a pandas DataFrame
df_subsidy = pd.read_excel(file_name)

# Display the first 5 rows
display(df_subsidy.head())
# Out:
#         CATEGORY RUNNING OK    Unnamed: 2 DEFECTIVE    Unnamed: 4 DOOR LOCK  \
# 0            NaN     COUNTS  SUBSIDY  AMT    COUNTS  SUBSIDY  AMT    COUNTS
# 1       CS Rural          1      0.000058         0             0         0
# 2  CS Rural (DS)        219      0.029656       346      0.030822        12
# 3       CS Urban          1      0.000146         0             0         0
# 4  CS Urban (DS)        105      0.021387         8      0.008154         3
#
#      Unnamed: 6   TOTAL    Unnamed: 8
# 0  SUBSIDY  AMT  COUNTS  SUBSIDY  AMT
# 1             0       1      0.000058
# 2      0.000973     577      0.061451
# 3             0       1      0.000146
# 4      0.001917     116      0.031457

# %%
df_subsidy_reloaded = df_subsidy_reloaded.fillna('')
display(df_subsidy_reloaded.head())
# Out:
#       Unnamed: 0  COUNTS  SUBSIDY  AMT  COUNTS.1  SUBSIDY  AMT.1  COUNTS.2  \
# 0       CS Rural       1      0.000058         0        0.000000         0
# 1  CS Rural (DS)     219      0.029656       346        0.030822        12
# 2       CS Urban       1      0.000146         0        0.000000         0
# 3  CS Urban (DS)     105      0.021387         8        0.008154         3
# 4  DS - Rural 1a  747055     63.998359    400804       34.014576     11658
#
#    SUBSIDY  AMT.2  COUNTS.3  SUBSIDY  AMT.3
# 0        0.000000         1        0.000058
# 1        0.000973       577        0.061451
# 2        0.000000         1        0.000146
# 3        0.001917       116        0.031457
# 4        0.871637   1159517       98.884572

# %%
# Check for missing values in each column
missing_values = df_subsidy_reloaded.isnull().sum()

# Display the count of missing values per column
print("Missing values per column in df_subsidy_reloaded:")
display(missing_values)
# Out:
# Missing values per column in df_subsidy_reloaded:
# Unnamed: 0        0
# COUNTS            0
# SUBSIDY  AMT      0
# COUNTS.1          0
# SUBSIDY  AMT.1    0
# COUNTS.2          0
# SUBSIDY  AMT.2    0
# COUNTS.3          0
# SUBSIDY  AMT.3    0
# dtype: int64

# %%
# Save the DataFrame to an Excel file
output_filename = 'CAT_unit_subsidy.xlsx'
df_subsidy_reloaded.to_excel(output_filename, index=False)

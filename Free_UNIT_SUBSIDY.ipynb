# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit198181/JBVNL/blob/main/Free_UNIT_SUBSIDY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import io
import pandas as pd

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-cd00afa6-46c1-4cb8-aef4-fdd750d99575" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd00afa6-46c1-4cb8-aef4-fdd750d99575">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-055d2676-f65a-420f-9528-b66090ea3699" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-055d2676-f65a-420f-9528-b66090ea3699">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
# Read the uploaded Excel file into a DataFrame
area_df = pd.read_excel(io.BytesIO(uploaded['area.xlsx']))

# Fill NaN values with empty strings
area_df = area_df.fillna('')

# Display the first 10 rows of the DataFrame
display(area_df.head(10))
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 RUNNING OK    Unnamed: 4 DEFECTIVE  \
# 0       AREA     CIRCLE   DIVISION     COUNTS  SUBSIDY  AMT    COUNTS
# 1    DHANBAD                           246135     29.865381     40232
# 2                  CHAS                169339     19.547979     19872
# 3                             CHAS      78461      9.625551      9267
# 4                          LOYABAD      31678      3.787061      5056
# 5                         TENUGHAT      59200      6.135367      5549
# 6               DHANBAD                 76796     10.317403     20360
# 7                          DHANBAD      30080       4.38607       774
# 8                        GOBINDPUR      12846      1.675408     16482
# 9                           JHARIA      14707      1.859315      1547
#
#      Unnamed: 6 DOOR LOCK    Unnamed: 8   TOTAL   Unnamed: 10
# 0  SUBSIDY  AMT    COUNTS  SUBSIDY  AMT  COUNTS  SUBSIDY  AMT
# 1      3.914855      3372      0.347845  289739     34.128082
# ...

# %%
# Save the DataFrame to an Excel file
output_filename = 'summary_area_wise_free_units.xlsx'
df_blanked.to_excel(output_filename, index=False)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7847fa7b-7a45-44ce-8527-68a1efe09bc7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7847fa7b-7a45-44ce-8527-68a1efe09bc7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Task
# Load the data from the "cat_subsidy.xlsx" file into a pandas DataFrame and analyze its structure to understand how to replicate the sheet table format.

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Load the data from the "cat_subsidy.xlsx" file into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the data from the "cat_subsidy.xlsx" file into a pandas DataFrame.

# %%
df_cat_subsidy = pd.read_excel('subsidy_sheet.xlsx')

# %% [markdown]
# ## Inspect the data
#
# ### Subtask:
# Display the first few rows and the column information to understand the basic structure and data types.

# %% [markdown]
# **Reasoning**:
# Display the first few rows and the column information of the DataFrame to understand its structure and data types as requested by the subtask.

# %%
display(df_cat_subsidy.head())
display(df_cat_subsidy.info())
# Out:
#         CATEGORY RUNNING OK    Unnamed: 2 DEFECTIVE    Unnamed: 4 DOOR LOCK  \
# 0            NaN     COUNTS  SUBSIDY  AMT    COUNTS  SUBSIDY  AMT    COUNTS
# 1       CS Rural          1      0.000058         0             0         0
# 2  CS Rural (DS)        219      0.029656       346      0.030822        12
# 3       CS Urban          1      0.000146         0             0         0
# 4  CS Urban (DS)        105      0.021387         8      0.008154         3
#
#      Unnamed: 6   TOTAL    Unnamed: 8
# 0  SUBSIDY  AMT  COUNTS  SUBSIDY  AMT
# 1             0       1      0.000058
# 2      0.000973     577      0.061451
# 3             0       1      0.000146
# 4      0.001917     116      0.031457
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CATEGORY    11 non-null     object
#  1   RUNNING OK  12 non-null     object
# ...

# %% [markdown]
# ## Analyze potential formatting
#
# ### Subtask:
# If the structure is complex (e.g., multi-level headers), analyze the data to identify how the table is organized in the original sheet.

# %% [markdown]
# **Reasoning**:
# Examine the first few rows of the df_cat_subsidy DataFrame to identify if the header spans multiple rows and determine how to handle the header when reading the data.

# %%
display(df_cat_subsidy.head())
# Out:
#         CATEGORY RUNNING OK    Unnamed: 2 DEFECTIVE    Unnamed: 4 DOOR LOCK  \
# 0            NaN     COUNTS  SUBSIDY  AMT    COUNTS  SUBSIDY  AMT    COUNTS
# 1       CS Rural          1      0.000058         0             0         0
# 2  CS Rural (DS)        219      0.029656       346      0.030822        12
# 3       CS Urban          1      0.000146         0             0         0
# 4  CS Urban (DS)        105      0.021387         8      0.008154         3
#
#      Unnamed: 6   TOTAL    Unnamed: 8
# 0  SUBSIDY  AMT  COUNTS  SUBSIDY  AMT
# 1             0       1      0.000058
# 2      0.000973     577      0.061451
# 3             0       1      0.000146
# 4      0.001917     116      0.031457

# %% [markdown]
# **Reasoning**:
# The header information appears to span two rows (row 0 and row 1 in the original sheet), with the first row containing broader categories like 'RUNNING OK', 'DEFECTIVE', 'DOOR LOCK', and 'TOTAL', and the second row providing specific metrics like 'COUNTS' and 'SUBSIDY AMT' under those categories. Row 0 also has "CATEGORY" which seems to be the main column. To correctly interpret this structure, we need to read the data again, skipping the first row and using the second row as the header. We can then combine the information from the first two rows to create meaningful column names programmatically.

# %%
df_cat_subsidy = pd.read_excel('cat_subsidy.xlsx', skiprows=1, header=0)
display(df_cat_subsidy.head())
# Out:
#       Unnamed: 0  COUNTS  SUBSIDY  AMT  COUNTS.1  SUBSIDY  AMT.1  COUNTS.2  \
# 0       CS Rural       1      0.000058         0        0.000000         0
# 1  CS Rural (DS)     219      0.029656       346        0.030822        12
# 2       CS Urban       1      0.000146         0        0.000000         0
# 3  CS Urban (DS)     105      0.021387         8        0.008154         3
# 4  DS - Rural 1a  747055     63.998359    400804       34.014576     11658
#
#    SUBSIDY  AMT.2  COUNTS.3  SUBSIDY  AMT.3
# 0        0.000000         1        0.000058
# 1        0.000973       577        0.061451
# 2        0.000000         1        0.000146
# 3        0.001917       116        0.031457
# 4        0.871637   1159517       98.884572

# %% [markdown]
# **Reasoning**:
# The current column names are not descriptive. The first column should be named 'CATEGORY'. The subsequent columns represent 'COUNTS' and 'SUBSIDY AMT' for 'RUNNING OK', 'DEFECTIVE', 'DOOR LOCK', and 'TOTAL'. We need to rename the columns to reflect this structure.

# %%
new_columns = ['CATEGORY', 'RUNNING OK - COUNTS', 'RUNNING OK - SUBSIDY AMT',
               'DEFECTIVE - COUNTS', 'DEFECTIVE - SUBSIDY AMT',
               'DOOR LOCK - COUNTS', 'DOOR LOCK - SUBSIDY AMT',
               'TOTAL - COUNTS', 'TOTAL - SUBSIDY AMT']
df_cat_subsidy.columns = new_columns
display(df_cat_subsidy.head())
# Out:
#         CATEGORY  RUNNING OK - COUNTS  RUNNING OK - SUBSIDY AMT  \
# 0       CS Rural                    1                  0.000058
# 1  CS Rural (DS)                  219                  0.029656
# 2       CS Urban                    1                  0.000146
# 3  CS Urban (DS)                  105                  0.021387
# 4  DS - Rural 1a               747055                 63.998359
#
#    DEFECTIVE - COUNTS  DEFECTIVE - SUBSIDY AMT  DOOR LOCK - COUNTS  \
# 0                   0                 0.000000                   0
# 1                 346                 0.030822                  12
# 2                   0                 0.000000                   0
# 3                   8                 0.008154                   3
# 4              400804                34.014576               11658
#
#    DOOR LOCK - SUBSIDY AMT  TOTAL - COUNTS  TOTAL - SUBSIDY AMT
# 0                 0.000000               1             0.000058
# ...

# %% [markdown]
# ## Discuss desired output
#
# ### Subtask:
# Based on the inspection, we can discuss what aspects of the "sheet table format" you want to replicate in the output.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The initial data load resulted in a DataFrame where the first row contained the actual header information, and all columns were of the 'object' data type.
# *   The original Excel file contained a multi-level header structure spanning two rows.
# *   By skipping the first row and using the second row as the header during reloading, the data was successfully loaded, and generic column names like 'COUNTS' and 'SUBSIDY AMT' were assigned, along with numerical suffixes for duplicated names.
# *   The column names were successfully updated to be more descriptive, such as 'RUNNING OK - COUNTS', 'DEFECTIVE - SUBSIDY AMT', reflecting the original multi-level header structure in a flattened format.
#
# ### Insights or Next Steps
#
# *   The current flattened header structure with combined category and metric names is suitable for further data analysis.
# *   The next step would likely involve analyzing the data within this structured DataFrame to extract meaningful insights based on the counts and subsidy amounts for different categories and states.

# %%
# Save the DataFrame to an Excel file
output_filename = 'summary_category_wise_free.xlsx'
df_cat_subsidy.to_excel(output_filename, index=False)

# %%
display(df_cat_subsidy.head())
# Out:
#         CATEGORY  RUNNING OK - COUNTS  RUNNING OK - SUBSIDY AMT  \
# 0       CS Rural                    1                  0.000058
# 1  CS Rural (DS)                  219                  0.029656
# 2       CS Urban                    1                  0.000146
# 3  CS Urban (DS)                  105                  0.021387
# 4  DS - Rural 1a               747055                 63.998359
#
#    DEFECTIVE - COUNTS  DEFECTIVE - SUBSIDY AMT  DOOR LOCK - COUNTS  \
# 0                   0                 0.000000                   0
# 1                 346                 0.030822                  12
# 2                   0                 0.000000                   0
# 3                   8                 0.008154                   3
# 4              400804                34.014576               11658
#
#    DOOR LOCK - SUBSIDY AMT  TOTAL - COUNTS  TOTAL - SUBSIDY AMT
# 0                 0.000000               1             0.000058
# ...

# %%
# Save the DataFrame to an Excel file
output_filename = 'summary_category_wise_free.xlsx'
df_cat_subsidy.to_excel(output_filename, index=False)

# %% [markdown]
# # Task
# Replicate the format of the sheet "area.xlsx" by loading the data from "area.xlsx", skipping the first row, setting the second row as the header, and cleaning the column names to combine information from the original first two rows.

# %% [markdown]
# ## Load the data
#
# ### Subtask:
# Reload the data from "area.xlsx" into a DataFrame, skipping the first row.

# %% [markdown]
# **Reasoning**:
# Reload the data from "area.xlsx" into a DataFrame, skipping the first row, as instructed by the subtask.

# %%
area_df = pd.read_excel('area.xlsx', skiprows=1)
display(area_df.head())
# Out:
#       AREA CIRCLE  DIVISION  COUNTS SUBSIDY  AMT COUNTS.1 SUBSIDY  AMT.1  \
# 0  DHANBAD    NaN       NaN  246135    29.865381    40232       3.914855
# 1      NaN   CHAS       NaN  169339    19.547979    19872       1.790223
# 2      NaN    NaN      CHAS   78461     9.625551     9267       0.750753
# 3      NaN    NaN   LOYABAD   31678     3.787061     5056       0.479748
# 4      NaN    NaN  TENUGHAT   59200     6.135367     5549       0.559721
#
#   COUNTS.2 SUBSIDY  AMT.2 COUNTS.3 SUBSIDY  AMT.3
# 0     3372       0.347845   289739      34.128082
# 1     1636        0.14357   190847      21.481771
# 2     1367       0.121329    89095      10.497633
# 3      144       0.012241    36878       4.279051
# 4      125           0.01    64874       6.705088

# %% [markdown]
# **Reasoning**:
# Set the second row as the header for the `area_df` DataFrame.

# %%
area_df = pd.read_excel('area.xlsx', skiprows=1, header=0)
display(area_df.head())
# Out:
#       AREA CIRCLE  DIVISION  COUNTS SUBSIDY  AMT COUNTS.1 SUBSIDY  AMT.1  \
# 0  DHANBAD    NaN       NaN  246135    29.865381    40232       3.914855
# 1      NaN   CHAS       NaN  169339    19.547979    19872       1.790223
# 2      NaN    NaN      CHAS   78461     9.625551     9267       0.750753
# 3      NaN    NaN   LOYABAD   31678     3.787061     5056       0.479748
# 4      NaN    NaN  TENUGHAT   59200     6.135367     5549       0.559721
#
#   COUNTS.2 SUBSIDY  AMT.2 COUNTS.3 SUBSIDY  AMT.3
# 0     3372       0.347845   289739      34.128082
# 1     1636        0.14357   190847      21.481771
# 2     1367       0.121329    89095      10.497633
# 3      144       0.012241    36878       4.279051
# 4      125           0.01    64874       6.705088

# %% [markdown]
# ## Clean column names
#
# ### Subtask:
# Combine the information from the original first two rows to create meaningful and descriptive column names.

# %% [markdown]
# **Reasoning**:
# The error indicates a mismatch in the number of columns. The DataFrame currently has 11 columns, but the new column list only has 9. This suggests that there are two extra columns in the DataFrame that need to be accounted for or removed. Based on the previous output of `area_df.head()`, there appear to be two unnamed columns between 'AREA', 'CIRCLE', and 'DIVISION' which are not included in the new column list. Let's re-examine the column names of `area_df` to identify the extra columns and create a new column list that matches the DataFrame's column count.

# %%
print(area_df.columns)
# Out:
# Index(['AREA', 'CIRCLE', 'DIVISION', 'COUNTS', 'SUBSIDY  AMT', 'COUNTS.1',
#        'SUBSIDY  AMT.1', 'COUNTS.2', 'SUBSIDY  AMT.2', 'COUNTS.3',
#        'SUBSIDY  AMT.3'],
#       dtype='object')

# %% [markdown]
# **Reasoning**:
# The previous output shows that the DataFrame has 11 columns: 'AREA', 'CIRCLE', 'DIVISION', 'COUNTS', 'SUBSIDY AMT', 'COUNTS.1', 'SUBSIDY AMT.1', 'COUNTS.2', 'SUBSIDY AMT.2', 'COUNTS.3', and 'SUBSIDY AMT.3'. The 'CIRCLE' and 'DIVISION' columns were not accounted for in the previous attempt to rename columns. We need to include these in the new column list to match the DataFrame's column count. The subsequent columns correspond to 'RUNNING OK', 'DEFECTIVE', 'DOOR LOCK', and 'TOTAL' for both 'COUNTS' and 'SUBSIDY AMT', as identified from the original sheet structure. Let's create a new list of 11 column names that accurately reflect this structure and then assign it to the DataFrame's columns.

# %%
new_columns = ['AREA', 'CIRCLE', 'DIVISION',
               'RUNNING OK - COUNTS', 'RUNNING OK - SUBSIDY AMT',
               'DEFECTIVE - COUNTS', 'DEFECTIVE - SUBSIDY AMT',
               'DOOR LOCK - COUNTS', 'DOOR LOCK - SUBSIDY AMT',
               'TOTAL - COUNTS', 'TOTAL - SUBSIDY AMT']
area_df.columns = new_columns
display(area_df.head())
# Out:
#       AREA CIRCLE  DIVISION RUNNING OK - COUNTS RUNNING OK - SUBSIDY AMT  \
# 0  DHANBAD    NaN       NaN              246135                29.865381
# 1      NaN   CHAS       NaN              169339                19.547979
# 2      NaN    NaN      CHAS               78461                 9.625551
# 3      NaN    NaN   LOYABAD               31678                 3.787061
# 4      NaN    NaN  TENUGHAT               59200                 6.135367
#
#   DEFECTIVE - COUNTS DEFECTIVE - SUBSIDY AMT DOOR LOCK - COUNTS  \
# 0              40232                3.914855               3372
# 1              19872                1.790223               1636
# 2               9267                0.750753               1367
# 3               5056                0.479748                144
# 4               5549                0.559721                125
#
#   DOOR LOCK - SUBSIDY AMT TOTAL - COUNTS TOTAL - SUBSIDY AMT
# 0                0.347845         289739           34.128082
# ...

# %% [markdown]
# ## Display the updated dataframe
#
# ### Subtask:
# Display the first few rows of the DataFrame with the new column names to verify the format.

# %% [markdown]
# **Reasoning**:
# Display the first few rows and the column information of the DataFrame to verify the format and data types of the cleaned data.

# %%
display(area_df.head(10))
display(area_df.info())
# Out:
#       AREA   CIRCLE   DIVISION RUNNING OK - COUNTS RUNNING OK - SUBSIDY AMT  \
# 0  DHANBAD      NaN        NaN              246135                29.865381
# 1      NaN     CHAS        NaN              169339                19.547979
# 2      NaN      NaN       CHAS               78461                 9.625551
# 3      NaN      NaN    LOYABAD               31678                 3.787061
# 4      NaN      NaN   TENUGHAT               59200                 6.135367
# 5      NaN  DHANBAD        NaN               76796                10.317403
# 6      NaN      NaN    DHANBAD               30080                  4.38607
# 7      NaN      NaN  GOBINDPUR               12846                 1.675408
# 8      NaN      NaN     JHARIA               14707                 1.859315
# 9      NaN      NaN      NIRSA               19163                  2.39661
#
#   DEFECTIVE - COUNTS DEFECTIVE - SUBSIDY AMT DOOR LOCK - COUNTS  \
# 0              40232                3.914855               3372
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The data from "area.xlsx" was successfully loaded into a DataFrame (`area_df`), skipping the first row and setting the second row as the header.
# *   The column names were successfully updated to be more descriptive by combining information from the original first two rows and including the 'CIRCLE' and 'DIVISION' columns. The new column names are 'AREA', 'CIRCLE', 'DIVISION', 'RUNNING OK - COUNTS', 'RUNNING OK - SUBSIDY AMT', 'DEFECTIVE - COUNTS', 'DEFECTIVE - SUBSIDY AMT', 'DOOR LOCK - COUNTS', 'DOOR LOCK - SUBSIDY AMT', 'TOTAL - COUNTS', and 'TOTAL - SUBSIDY AMT'.
# *   The verification steps confirmed that the DataFrame's format and column names matched the desired structure.
#
# ### Insights or Next Steps
#
# *   The data types for the numerical columns (e.g., 'COUNTS' and 'SUBSIDY AMT') should be converted from 'object' to appropriate numeric types (e.g., integer or float) to enable numerical analysis.
# *   Further data cleaning may be required to handle any non-numeric values that prevented the initial automatic type inference.

# %%
# Fill NaN values in 'AREA', 'CIRCLE', and 'DIVISION' columns using forward fill
area_df['AREA'] = area_df['AREA'].fillna(method='ffill')
area_df['CIRCLE'] = area_df['CIRCLE'].fillna(method='ffill')
area_df['DIVISION'] = area_df['DIVISION'].fillna(method='ffill')

# Display the first 10 rows of the updated DataFrame
display(area_df.head(10))
# Out:
# /tmp/ipython-input-2283150330.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   area_df['AREA'] = area_df['AREA'].fillna(method='ffill')
# /tmp/ipython-input-2283150330.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   area_df['CIRCLE'] = area_df['CIRCLE'].fillna(method='ffill')
# /tmp/ipython-input-2283150330.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   area_df['DIVISION'] = area_df['DIVISION'].fillna(method='ffill')
#       AREA   CIRCLE   DIVISION RUNNING OK - COUNTS RUNNING OK - SUBSIDY AMT  \
# 0  DHANBAD      NaN        NaN              246135                29.865381
# 1  DHANBAD     CHAS        NaN              169339                19.547979
# ...

# %%
# Display the data types and non-null counts
area_df.info()

# Check for any remaining null values
print("\nRemaining null values per column:")
print(area_df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   AREA                      74 non-null     object
#  1   CIRCLE                    74 non-null     object
#  2   DIVISION                  74 non-null     object
#  3   RUNNING OK - COUNTS       74 non-null     object
#  4   RUNNING OK - SUBSIDY AMT  74 non-null     object
#  5   DEFECTIVE - COUNTS        74 non-null     object
#  6   DEFECTIVE - SUBSIDY AMT   74 non-null     object
#  7   DOOR LOCK - COUNTS        74 non-null     object
#  8   DOOR LOCK - SUBSIDY AMT   74 non-null     object
#  9   TOTAL - COUNTS            74 non-null     object
#  10  TOTAL - SUBSIDY AMT       74 non-null     object
# dtypes: object(11)
# memory usage: 6.5+ KB
#
# Remaining null values per column:
# AREA                        0
# CIRCLE                      0
# ...

# %%
# Replace all NaN values in the DataFrame with empty strings
area_df = area_df.fillna('')

# Display the first 10 rows of the updated DataFrame
display(area_df.head(10))
# Out:
#       AREA   CIRCLE   DIVISION RUNNING OK - COUNTS RUNNING OK - SUBSIDY AMT  \
# 0  DHANBAD                                  246135                29.865381
# 1  DHANBAD     CHAS                         169339                19.547979
# 2  DHANBAD     CHAS       CHAS               78461                 9.625551
# 3  DHANBAD     CHAS    LOYABAD               31678                 3.787061
# 4  DHANBAD     CHAS   TENUGHAT               59200                 6.135367
# 5  DHANBAD  DHANBAD   TENUGHAT               76796                10.317403
# 6  DHANBAD  DHANBAD    DHANBAD               30080                  4.38607
# 7  DHANBAD  DHANBAD  GOBINDPUR               12846                 1.675408
# 8  DHANBAD  DHANBAD     JHARIA               14707                 1.859315
# 9  DHANBAD  DHANBAD      NIRSA               19163                  2.39661
#
#   DEFECTIVE - COUNTS DEFECTIVE - SUBSIDY AMT DOOR LOCK - COUNTS  \
# 0              40232                3.914855               3372
# ...

# %%
# Save the DataFrame to an Excel file
output_filename = 'AREA_SUBSIDY.xlsx'
area_df.to_excel(output_filename, index=False)

# Download the file
files.download(output_filename)

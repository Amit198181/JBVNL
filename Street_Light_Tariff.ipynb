# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit198181/JBVNL/blob/main/Street_Light_Tariff.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Assuming df is still available from the previous step.
# Display the first 15 rows of the DataFrame.
print("--- Complete Merged Data (First 15 Rows) ---")
# Reset index for clean markdown table output
df_display = df.reset_index(drop=True)
print(df_display.head(15).to_markdown(index=True, numalign="left", stralign="left"))

# %% [markdown]
# ```text?code_stdout&code_event_index=2
# --- Complete Merged Data (First 15 Rows) ---
# |    | Distribution Utility Name                                       | State/UT          | Consumer Category Name             | Tariff Scheme Name / Rate Code   | Fixed/Demand Charges (Unit)                            | Energy Charges (Paise/kWh, Rs/unit)             | Applicable Rebates or Surcharges                                                 | Special Regulatory Provisions or Subsidies                                                              | Official Citation / Reference                  |
# |:---|:----------------------------------------------------------------|:------------------|:-----------------------------------|:---------------------------------|:-------------------------------------------------------|:------------------------------------------------|:---------------------------------------------------------------------------------|:--------------------------------------------------------------------------------------------------------|:-----------------------------------------------|
# | 0  | APEPDCL/APSPDCL/APCPDCL                                         | Andhra Pradesh    | Street Lighting (SL)               | LT-IV / LT-VII                   | Rs. 75/- per kW/month                                  | Rs. 7.15/- per kWh (Flat Rate)                  | FPPCA capped at 40 Paise per unit.                                               | Rates are uniform across all three AP DISCOMs; effective for FY 2025-26.                                | APERC Tariff Schedule FY 2025-26               |
# | 1  | Assam Power Distribution Company Limited (APDCL)                | Assam             | Street Light (SL)                  | LT-SL/HT-SL                      | nan                                                    | nan                                             | nan                                                                              | Tariff determined by AERC.                                                                              | AERC Tariff Order FY 2024-25                   |
# | 2  | North/South Bihar Power Distribution Co. Ltd. (NBPDCL / SBPDCL) | Bihar             | Street Light Service (SLS)         | LT-IV/HT-IV                      | LT: Rs. 80/- per kW/month. HT: Rs. 80/- per kVA/month. | Not explicitly detailed in snippet.             | nan                                                                              | Subject to Government of Bihar Subsidy. Uniform tariff for both DISCOMs.                                | BERC Tariff Order FY 2024-25                   |
# | 3  | Chhattisgarh State Power Distribution Company Limited (CSPDCL)  | Chhattisgarh      | Public Street Lighting (PSL)       | nan                              | nan                                                    | nan                                             | nan                                                                              | Tariff Order effective from FY 2024-25.                                                                 | CSERC Tariff Order FY 2024-25                  |
# | 4  | BSES Rajdhani Power Ltd. (BRPL)                                 | Delhi             | Public Utilities (Public Lighting) | LT-6                             | Rs. 250/- per kVA/month                                | Rs. 6.25/- per kVAh                             | 20% TOD Rebate/Surcharge on Energy Charges.                                      | Additional Surcharges (e.g., Pension Trust Charges) applicable. PPAC is extra.                          | DERC Tariff Schedule FY 2021-22 (Used as base) |
# | 5  | BSES Yamuna Power Ltd. (BYPL)                                   | Delhi             | Public Utilities (Public Lighting) | LT-6                             | Rs. 250/- per kVA/month                                | Rs. 6.25/- per kVAh                             | 20% TOD Rebate/Surcharge on Energy Charges.                                      | Maintenance Charges (if maintained by DISCOM) applicable.                                               | DERC Tariff Schedule FY 2021-22 (Used as base) |
# | 6  | Tata Power Delhi Distribution Ltd. (TPDDL)                      | Delhi             | Public Utilities (Public Lighting) | LT-6                             | Rs. 250/- per kVA/month                                | Rs. 6.25/- per kVAh                             | 20% TOD Rebate/Surcharge on Energy Charges.                                      | Additional Surcharges and PPAC are applicable.                                                          | DERC Tariff Schedule FY 2021-22 (Used as base) |
# | 7  | New Delhi Municipal Council (NDMC)                              | Delhi             | Public Utilities (Street Lights)   | LT-6                             | Rs. 250/- per kVA/month                                | Rs. 6.25/- per kVAh                             | 20% TOD Rebate/Surcharge on Energy Charges.                                      | NDMC is a Deemed Licensee; DERC Tariff applies.                                                         | DERC Tariff Schedule FY 2021-22 (Used as base) |
# | 8  | Military Engineering Services (MES - New Delhi Area)            | Delhi             | Public Utilities (Street Lights)   | nan                              | Subject to DERC approved tariffs (same as LT-6)        | Subject to DERC approved tariffs (same as LT-6) | Not detailed, generally follows DERC regulations.                                | MES follows the DERC-determined tariff structure.                                                       | DERC Coordination Forum Minutes/Tariff Orders  |
# | 9  | Electricity Department, Government of Goa                       | Goa               | Public Lighting                    | nan                              | nan                                                    | nan                                             | nan                                                                              | Tariff set by JERC (Goa & UTs).                                                                         | JERC Tariff Order FY 2024-25                   |
# | 10 | Gujarat DISCOMs (DGVCL, MGVCL, PGVCL, UGVCL)                    | Gujarat           | Street Light (SL)                  | LT-SL / HT-SL                    | Rs. 70/- per Installation per Month                    | Not explicitly detailed in snippet.             | FPPPA applicable. Green Power Tariff (Rs. 1.50/kWh) optional.                    | Uniform Tariff across all four state DISCOMs. Effective from June 1, 2024.                              | GERC Tariff Order FY 2024-25                   |
# | 11 | Torrent Power (Ahmedabad, Surat, Gandhinagar)                   | Gujarat           | Street Lighting (STRLGT)           | nan                              | Not explicitly detailed in snippet.                    | Not explicitly detailed in snippet.             | FPPPA applicable (e.g., Rs. 3.39 per unit in Ahmedabad).                         | Separate Tariff Orders for Torrent's licensed areas. Effective from June 1, 2024.                       | GERC Tariff Orders FY 2024-25                  |
# | 12 | Dakshin/Uttar Haryana Bijli Vitran Nigam (DHBVN/UHBVN)          | Haryana           | Street Light (SL)                  | LT-V / HT-IV                     | Not detailed in snippet.                               | Not detailed in snippet.                        | FPPAS (Fuel and Power Purchase Adjustment Surcharge) is variable and applicable. | Uniform Tariff for both DHBVN and UHBVN. Effective from April 1, 2024.                                  | HERC Tariff Order FY 2024-25                   |
# | 13 | Himachal Pradesh State Electricity Board Ltd. (HPSEBL)          | Himachal Pradesh  | Public Lighting (PL)               | LT-PL / HT-PL                    | Not detailed in snippet.                               | Not detailed in snippet.                        | Night Time Concession is Not Applicable.                                         | Tariff Order is applicable throughout the State of Himachal Pradesh.                                    | HPERC Tariff Order FY 2023-24                  |
# | 14 | Jammu/Kashmir Power Distribution Corporation Ltd. (JPDCL/KPDCL) | J&K & Ladakh (UT) | Public Street Lighting (PSL)       | nan                              | Not detailed in snippet.                               | Not detailed in snippet.                        | Not detailed in snippet.                                                         | Uniform Tariff for both DISCOMs. Government provides subsidy to maintain existing rates for FY 2024-25. | JERC Tariff Order FY 2024-25                   |
#
# ```
#
# The complete merged data of all utilities contains **44 records**.
#
# As the full table is quite large, I'm providing the first **15 rows** of the merged data below to give you a detailed look at the structure and content.
#
# The full dataset, including all 44 utility records, is available in the **`Validated_Merged_Tariff_Data.xlsx`** file you downloaded previously.
#
# ### Complete Merged Data (First 15 Rows)
#
# | | Distribution Utility Name | State/UT | Consumer Category Name | Tariff Scheme Name / Rate Code | Fixed/Demand Charges (Unit) | Energy Charges (Paise/kWh, Rs/unit) | Applicable Rebates or Surcharges | Special Regulatory Provisions or Subsidies | Official Citation / Reference |
# |:---|:---|:---|:---|:---|:---|:---|:---|:---|:---|
# | 0 | APEPDCL/APSPDCL/APCPDCL | Andhra Pradesh | Street Lighting (SL) | LT-IV / LT-VII | Rs. 75/- per kW/month | Rs. 7.15/- per kWh (Flat Rate) | FPPCA capped at 40 Paise per unit. | Rates are uniform across all three AP DISCOMs; effective for FY 2025-26. | APERC Tariff Schedule FY 2025-26 |
# | 1 | Assam Power Distribution Company Limited (APDCL) | Assam | Street Light (SL) | LT-SL/HT-SL | nan | nan | nan | Tariff determined by AERC. | AERC Tariff Order FY 2024-25 |
# | 2 | North/South Bihar Power Distribution Co. Ltd. (NBPDCL / SBPDCL) | Bihar | Street Light Service (SLS) | LT-IV/HT-IV | LT: Rs. 80/- per kW/month. HT: Rs. 80/- per kVA/month. | Not explicitly detailed in snippet. | nan | Subject to Government of Bihar Subsidy. Uniform tariff for both DISCOMs. | BERC Tariff Order FY 2024-25 |
# | 3 | Chhattisgarh State Power Distribution Company Limited (CSPDCL) | Chhattisgarh | Public Street Lighting (PSL) | nan | nan | nan | nan | Tariff Order effective from FY 2024-25. | CSERC Tariff Order FY 2024-25 |
# | 4 | BSES Rajdhani Power Ltd. (BRPL) | Delhi | Public Utilities (Public Lighting) | LT-6 | Rs. 250/- per kVA/month | Rs. 6.25/- per kVAh | 20% TOD Rebate/Surcharge on Energy Charges. | Additional Surcharges (e.g., Pension Trust Charges) applicable. PPAC is extra. | DERC Tariff Schedule FY 2021-22 (Used as base) |
# | 5 | BSES Yamuna Power Ltd. (BYPL) | Delhi | Public Utilities (Public Lighting) | LT-6 | Rs. 250/- per kVA/month | Rs. 6.25/- per kVAh | 20% TOD Rebate/Surcharge on Energy Charges. | Maintenance Charges (if maintained by DISCOM) applicable. | DERC Tariff Schedule FY 2021-22 (Used as base) |
# | 6 | Tata Power Delhi Distribution Ltd. (TPDDL) | Delhi | Public Utilities (Public Lighting) | LT-6 | Rs. 250/- per kVA/month | Rs. 6.25/- per kVAh | 20% TOD Rebate/Surcharge on Energy Charges. | Additional Surcharges and PPAC are applicable. | DERC Tariff Schedule FY 2021-22 (Used as base) |
# | 7 | New Delhi Municipal Council (NDMC) | Delhi | Public Utilities (Street Lights) | LT-6 | Rs. 250/- per kVA/month | Rs. 6.25/- per kVAh | 20% TOD Rebate/Surcharge on Energy Charges. | NDMC is a Deemed Licensee; DERC Tariff applies. | DERC Tariff Schedule FY 2021-22 (Used as base) |
# | 8 | Military Engineering Services (MES - New Delhi Area) | Delhi | Public Utilities (Street Lights) | nan | Subject to DERC approved tariffs (same as LT-6) | Subject to DERC approved tariffs (same as LT-6) | Not detailed, generally follows DERC regulations. | MES follows the DERC-determined tariff structure. | DERC Coordination Forum Minutes/Tariff Orders |
# | 9 | Electricity Department, Government of Goa | Goa | Public Lighting | nan | nan | nan | nan | Tariff set by JERC (Goa & UTs). | JERC Tariff Order FY 2024-25 |
# | 10 | Gujarat DISCOMs (DGVCL, MGVCL, PGVCL, UGVCL) | Gujarat | Street Light (SL) | LT-SL / HT-SL | Rs. 70/- per Installation per Month | Not explicitly detailed in snippet. | FPPPA applicable. Green Power Tariff (Rs. 1.50/kWh) optional. | Uniform Tariff across all four state DISCOMs. Effective from June 1, 2024. | GERC Tariff Order FY 2024-25 |
# | 11 | Torrent Power (Ahmedabad, Surat, Gandhinagar) | Gujarat | Street Lighting (STRLGT) | nan | Not explicitly detailed in snippet. | Not explicitly detailed in snippet. | FPPPA applicable (e.g., Rs. 3.39 per unit in Ahmedabad). | Separate Tariff Orders for Torrent's licensed areas. Effective from June 1, 2024. | GERC Tariff Orders FY 2024-25 |
# | 12 | Dakshin/Uttar Haryana Bijli Vitran Nigam (DHBVN/UHBVN) | Haryana | Street Light (SL) | LT-V / HT-IV | Not detailed in snippet. | Not detailed in snippet. | FPPAS (Fuel and Power Purchase Adjustment Surcharge) is variable and applicable. | Uniform Tariff for both DHBVN and UHBVN. Effective from April 1, 2024. | HERC Tariff Order FY 2024-25 |
# | 13 | Himachal Pradesh State Electricity Board Ltd. (HPSEBL) | Himachal Pradesh | Public Lighting (PL) | LT-PL / HT-PL | Not detailed in snippet. | Not detailed in snippet. | Night Time Concession is Not Applicable. | Tariff Order is applicable throughout the State of Himachal Pradesh. | HPERC Tariff Order FY 2023-24 |
# | 14 | Jammu/Kashmir Power Distribution Corporation Ltd. (JPDCL/KPDCL) | J\&K & Ladakh (UT) | Public Street Lighting (PSL) | nan | Not detailed in snippet. | Not detailed in snippet. | Not detailed in snippet. | Uniform Tariff for both DISCOMs. Government provides subsidy to maintain existing rates for FY 2024-25. | JERC Tariff Order FY 2024-25 |

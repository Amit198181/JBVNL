# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit198181/JBVNL/blob/main/Summary_HT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import os

uploaded = files.upload()

for fn in uploaded.keys():
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-43e8ab47-0b1e-45af-9cbb-91b12638d7f4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43e8ab47-0b1e-45af-9cbb-91b12638d7f4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

file_name = "HT_APR_AUG.xlsx"
df = pd.read_excel(file_name)

display(df.head())
# Out:
#      ZONE  CIRCLE     DIVISION   CONSNO   ACCOUNT_NO CONSUMER_STATUS  \
# 0  RANCHI  RANCHI  RANCHI EAST   RP4821  11220853642            LIVE
# 1  RANCHI  RANCHI  RANCHI EAST  RP12669  11220941508            LIVE
# 2     NaN     NaN          NaN      NaN  11240084805             NaN
# 3     NaN     NaN          NaN      NaN  11240084813             NaN
# 4  RANCHI  RANCHI  RANCHI EAST  ANG5107  11240084821            LIVE
#
#                             CONSUMER_NAME TARIFF_CODE  CONTRACTED_LOAD  \
# 0  Registrar Jharkhand Univ Of Technology         HTS            300.0
# 1                            PUNEET GUPTA         HTS            200.0
# 2                                     NaN         NaN              NaN
# 3                                     NaN         NaN              NaN
# 4           M/S J.K. POLYPLAST PROP SRI           HTS            250.0
#
#   CONSUMER_TYPE  ... LOAD_FACTOR_HTS_202506  SUPPLY_HOURS_HTS_202506  \
# ...

# %%
df_sorted = df.sort_values(by='OVERDRAWN_COUNT')
display(df_sorted.head())
# Out:
#          ZONE   CIRCLE  DIVISION   CONSNO   ACCOUNT_NO CONSUMER_STATUS  \
# 2724  DHANBAD     CHAS  TENUGHAT    KRH11  72250089598            LIVE
# 2723  DHANBAD  DHANBAD    JHARIA   MK1574  72250088702            LIVE
# 2722  DHANBAD  DHANBAD    JHARIA  SND1538  72250088656            LIVE
# 2721  DHANBAD  DHANBAD    JHARIA  SND1537  72250088621            LIVE
# 2735  DHANBAD  DHANBAD   DHANBAD   NB1739  72250212489            LIVE
#
#                           CONSUMER_NAME TARIFF_CODE  CONTRACTED_LOAD  \
# 2724                         AMIT KUMAR         HTS            300.0
# 2723                 CHEAP FUEL INDUTRY         HTS            160.0
# 2722  KALYANESWARI TASRA MINING PVT LTD         HTS            400.0
# 2721          KALYANESWARI TASRA MINING         HTS            400.0
# 2735                        MIHIR KUMAR         HTS            125.0
#
#      CONSUMER_TYPE  ... BILLED_UNITS_HTS_202508  MDI_HTS_202508  \
# ...

# %%
df.to_excel("overdrawn_analysis.xlsx", index=False)
print("DataFrame saved to overdrawn_analysis.xlsx")
# Out:
# DataFrame saved to overdrawn_analysis.xlsx

# %%
# Count the number of times each consumer was overdrawn across all months
df['OVERDRAWN_COUNT'] = df[overdrawn_columns].sum(axis=1)

# Display the consumer account number and the overdrawn count
display(df[['ACCOUNT_NO', 'OVERDRAWN_COUNT']].head())
# Out:
#     ACCOUNT_NO  OVERDRAWN_COUNT
# 0  11220853642                0
# 1  11220941508                0
# 2  11240084805                0
# 3  11240084813                0
# 4  11240084821                0

# %%
# Identify the monthly maximum demand columns
mdi_columns = [col for col in df.columns if col.startswith('MDI_HTS_')]

# Compare monthly maximum demand with contracted load and create boolean columns for overdrawn
for col in mdi_columns:
  month_year = col.split('_')[-1]
  df[f'OVERDRAWN_{month_year}'] = df[col] > df['CONTRACTED_LOAD']

# Display the new columns indicating overdrawn status
overdrawn_columns = [col for col in df.columns if col.startswith('OVERDRAWN_')]
display(df[['CONTRACTED_LOAD'] + mdi_columns + overdrawn_columns].head())
# Out:
#    CONTRACTED_LOAD  MDI_HTS_202504  MDI_HTS_202505  MDI_HTS_202506  \
# 0            300.0             NaN            8.00            4.88
# 1            200.0             NaN             NaN          114.56
# 2              NaN           93.08           81.84           81.56
# 3              NaN          114.92          116.04          124.28
# 4            250.0          225.00          211.80          216.60
#
#    MDI_HTS_202507  MDI_HTS_202508  OVERDRAWN_202504  OVERDRAWN_202505  \
# 0            7.20            9.34             False             False
# 1          116.00          117.60             False             False
# 2           73.56             NaN             False             False
# 3           62.30             NaN             False             False
# 4          208.20          190.20             False             False
#
#    OVERDRAWN_202506  OVERDRAWN_202507  OVERDRAWN_202508
# 0             False             False             False
# ...

# %%
print(df.columns)
# Out:
# Index(['ZONE', 'CIRCLE', 'DIVISION', 'CONSNO', 'ACCOUNT_NO', 'CONSUMER_STATUS',
#        'CONSUMER_NAME', 'TARIFF_CODE', 'CONTRACTED_LOAD', 'CONSUMER_TYPE',
#        'METER_READER_NAME', 'MF_KWH', 'PREPAID_FLAG', 'MTR_CONSUMP_TYPE',
#        'BILLED_UNITS_HTS_202504', 'MDI_HTS_202504', 'BILLED_UNITS_HTS_202505',
#        'MDI_HTS_202505', 'BILLED_UNITS_HTS_202506', 'MDI_HTS_202506',
#        'LOAD_FACTOR_HTS_202506', 'SUPPLY_HOURS_HTS_202506',
#        'BILLED_UNITS_HTS_202507', 'MDI_HTS_202507', 'LOAD_FACTOR_HTS_202507',
#        'SUPPLY_HOURS_HTS_202507', 'BILLED_UNITS_HTS_202508', 'MDI_HTS_202508',
#        'LOAD_FACTOR_HTS_202508', 'SUPPLY_HOURS_HTS_202508'],
#       dtype='object')
